# %% [markdown]
# IMPORT NECESSARY LIBRARIES

# %%
# Importing necessary libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from tensorflow import keras

# %% [markdown]
# LOAD DATA

# %%
df = pd.read_csv('./datasets/datasets.csv')

# %% [markdown]
# PREPROCESS DATA

# %%
df.head()
# Out:
#    6  148  72  35    0  33.6  0.627  50  1
# 0  1   85  66  29    0  26.6  0.351  31  0
# 1  8  183  64   0    0  23.3  0.672  32  1
# 2  1   89  66  23   94  28.1  0.167  21  0
# 3  0  137  40  35  168  43.1  2.288  33  1
# 4  5  116  74   0    0  25.6  0.201  30  0

# %%
df.rename(columns={'6':'Pregnancies','148':'Glucose','72':'BloodPressure','35':'SkinThickness','0':'Insulin','33.6':'BMI','0.627':'DiabetesPedigreeFunction','50':'Age','1':'Outcome'
},inplace=True)

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            1       85             66             29        0  26.6
# 1            8      183             64              0        0  23.3
# 2            1       89             66             23       94  28.1
# 3            0      137             40             35      168  43.1
# 4            5      116             74              0        0  25.6
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.351   31        0
# 1                     0.672   32        1
# 2                     0.167   21        0
# 3                     2.288   33        1
# 4                     0.201   30        0

# %%
df.isna().value_counts()
# Out:
# Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  BMI    DiabetesPedigreeFunction  Age    Outcome
# False        False    False          False          False    False  False                     False  False      767
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   767.000000  767.000000     767.000000     767.000000  767.000000
# mean      3.842243  120.859192      69.101695      20.517601   79.903520
# std       3.370877   31.978468      19.368155      15.954059  115.283105
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   32.000000
# 75%       6.000000  140.000000      80.000000      32.000000  127.500000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  767.000000                767.000000  767.000000  767.000000
# mean    31.990482                  0.471674   33.219035    0.348110
# std      7.889091                  0.331497   11.752296    0.476682
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243500   24.000000    0.000000
# 50%     32.000000                  0.371000   29.000000    0.000000
# 75%     36.600000                  0.625000   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
df['Outcome'].value_counts()
# Out:
# Outcome
# 0    500
# 1    267
# Name: count, dtype: int64

# %% [markdown]
# VISUALIZE DATA

# %%
import warnings
import seaborn as sns
import matplotlib.pyplot as plt

# Your dataframe 'df' should be defined before this point

# Suppress FutureWarnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# Your seaborn code
sns.boxplot(x='Outcome', y='Glucose', data=df)
plt.title('Box Plot of Feature by Class')
plt.show()

# We can see that high glucose means higher chances of diabetes

# %%
import seaborn as sns

correlation_matrix = df.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# FEATURE SELECTION

# %%
X = df.drop('Outcome', axis='columns')  # 'Outcome' is the target variable
y = df['Outcome']

# %%
X.head()
# Out:
# C:\Users\abhik\AppData\Roaming\Python\Python311\site-packages\IPython\core\displayhook.py:281: UserWarning: Output cache limit (currently 1000 entries) hit.
# Flushing oldest 200 entries.
#   warn('Output cache limit (currently {sz} entries) hit.\n'
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            1       85             66             29        0  26.6
# 1            8      183             64              0        0  23.3
# 2            1       89             66             23       94  28.1
# 3            0      137             40             35      168  43.1
# 4            5      116             74              0        0  25.6
#
#    DiabetesPedigreeFunction  Age
# 0                     0.351   31
# 1                     0.672   32
# 2                     0.167   21
# 3                     2.288   33
# 4                     0.201   30

# %%
y.head()
# Out:
# 0    0
# 1    1
# 2    0
# 3    1
# 4    0
# Name: Outcome, dtype: int64

# %% [markdown]
# SPLIT THE DATA INTO TRAINING PART AND TESTING PART

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=20)

# %%
X_train.shape
# Out:
# (613, 8)

# %%
X_test.shape
# Out:
# (154, 8)

# %%
y_train.value_counts()
# Out:
# Outcome
# 0    400
# 1    213
# Name: count, dtype: int64

# %%
y_test.value_counts()
# Out:
# Outcome
# 0    100
# 1     54
# Name: count, dtype: int64

# %% [markdown]
# SCALE THE DATA

# %%
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# DEFINE CLASSIFIERS

# %%
model = keras.Sequential([
    keras.Input(shape=(X_train.shape[1],)),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dense(32, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])
optimizer = keras.optimizers.Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# %%
classifiers = {
    "Logistic Regression": LogisticRegression(C=1.1),
    "Decision Tree": DecisionTreeClassifier(),
    "Random Forest": RandomForestClassifier(),
    "AdaBoost": AdaBoostClassifier(),
    "SVM": SVC(C=0.2),
    "K-Nearest Neighbors": KNeighborsClassifier(),
    "Naive Bayes": GaussianNB(),
    "XGBoost": XGBClassifier(),
    "ANN": model,
}

# %% [markdown]
# TRAIN CLASSIFIER

# %%
def predict(name, classifier, X_test):
    if name == "ANN":
        y_pred = classifier.predict(X_test)
        y_pred = np.array(y_pred).flatten()
        for i in range(y_pred.size):
            if y_pred[i] >= 0.5:
                y_pred[i] = 1
            else:
                y_pred[i] = 0
    else:
        y_pred = classifier.predict(X_test)
    return y_pred

# %%
results = {}
best_classifiers = {}
y_pred_final = np.zeros((y_test.shape[0],))

for name, classifier in classifiers.items():
    if name == "ANN":
        classifier.fit(X_train, y_train, epochs=50, validation_split=0.2)
    else:
        classifier.fit(X_train, y_train)
    
    y_pred = predict(name, classifier, X_test)
    accuracy = accuracy_score(y_test, y_pred)
    classification_rep = classification_report(y_test, y_pred)
    
    if accuracy >= 0.8:
        y_pred_final = np.add(y_pred_final,np.array(y_pred))
        best_classifiers[name] = classifier
    
    results[name] = {
        "Accuracy": accuracy,
        "Classification Report": classification_rep
    }
# Out:
# Epoch 1/50
# 16/16 [==============================] - 1s 14ms/step - loss: 0.6651 - accuracy: 0.6449 - val_loss: 0.6426 - val_accuracy: 0.6748
# Epoch 2/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.6568 - accuracy: 0.6469 - val_loss: 0.6299 - val_accuracy: 0.6748
# Epoch 3/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.6425 - accuracy: 0.6490 - val_loss: 0.6184 - val_accuracy: 0.6992
# Epoch 4/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.6333 - accuracy: 0.6551 - val_loss: 0.6097 - val_accuracy: 0.6911
# Epoch 5/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.6243 - accuracy: 0.6490 - val_loss: 0.5941 - val_accuracy: 0.6992
# Epoch 6/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.6154 - accuracy: 0.6633 - val_loss: 0.5844 - val_accuracy: 0.7154
# Epoch 7/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.6054 - accuracy: 0.6816 - val_loss: 0.5692 - val_accuracy: 0.7073
# Epoch 8/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5954 - accuracy: 0.6694 - val_loss: 0.5569 - val_accuracy: 0.7236
# Epoch 9/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5852 - accuracy: 0.6980 - val_loss: 0.5450 - val_accuracy: 0.7317
# Epoch 10/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5786 - accuracy: 0.7041 - val_loss: 0.5326 - val_accuracy: 0.7154
# Epoch 11/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5693 - accuracy: 0.7102 - val_loss: 0.5234 - val_accuracy: 0.7398
# Epoch 12/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5600 - accuracy: 0.7143 - val_loss: 0.5130 - val_accuracy: 0.7398
# Epoch 13/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5580 - accuracy: 0.7082 - val_loss: 0.5069 - val_accuracy: 0.7642
# Epoch 14/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5517 - accuracy: 0.7163 - val_loss: 0.5080 - val_accuracy: 0.7561
# Epoch 15/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5468 - accuracy: 0.7245 - val_loss: 0.4955 - val_accuracy: 0.7642
# Epoch 16/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5380 - accuracy: 0.7327 - val_loss: 0.4922 - val_accuracy: 0.7642
# Epoch 17/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5356 - accuracy: 0.7367 - val_loss: 0.4890 - val_accuracy: 0.7642
# Epoch 18/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5290 - accuracy: 0.7327 - val_loss: 0.4817 - val_accuracy: 0.7642
# Epoch 19/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5217 - accuracy: 0.7327 - val_loss: 0.4790 - val_accuracy: 0.7724
# Epoch 20/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5211 - accuracy: 0.7347 - val_loss: 0.4708 - val_accuracy: 0.8130
# Epoch 21/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5103 - accuracy: 0.7510 - val_loss: 0.4672 - val_accuracy: 0.7805
# Epoch 22/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5042 - accuracy: 0.7633 - val_loss: 0.4634 - val_accuracy: 0.7886
# Epoch 23/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5023 - accuracy: 0.7714 - val_loss: 0.4608 - val_accuracy: 0.7886
# Epoch 24/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4984 - accuracy: 0.7653 - val_loss: 0.4716 - val_accuracy: 0.7642
# Epoch 25/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4944 - accuracy: 0.7571 - val_loss: 0.4570 - val_accuracy: 0.7805
# Epoch 26/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4908 - accuracy: 0.7735 - val_loss: 0.4548 - val_accuracy: 0.7805
# Epoch 27/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4855 - accuracy: 0.7673 - val_loss: 0.4546 - val_accuracy: 0.7724
# Epoch 28/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4822 - accuracy: 0.7694 - val_loss: 0.4602 - val_accuracy: 0.7886
# Epoch 29/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4827 - accuracy: 0.7694 - val_loss: 0.4588 - val_accuracy: 0.7967
# Epoch 30/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4871 - accuracy: 0.7673 - val_loss: 0.4527 - val_accuracy: 0.7805
# Epoch 31/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4748 - accuracy: 0.7714 - val_loss: 0.4547 - val_accuracy: 0.7805
# Epoch 32/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4723 - accuracy: 0.7878 - val_loss: 0.4509 - val_accuracy: 0.8049
# Epoch 33/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4746 - accuracy: 0.7755 - val_loss: 0.4707 - val_accuracy: 0.7724
# Epoch 34/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4652 - accuracy: 0.7796 - val_loss: 0.4519 - val_accuracy: 0.8130
# Epoch 35/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4641 - accuracy: 0.7714 - val_loss: 0.4605 - val_accuracy: 0.7642
# Epoch 36/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4646 - accuracy: 0.7816 - val_loss: 0.4521 - val_accuracy: 0.7886
# Epoch 37/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4607 - accuracy: 0.7816 - val_loss: 0.4520 - val_accuracy: 0.7967
# Epoch 38/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4652 - accuracy: 0.7633 - val_loss: 0.4564 - val_accuracy: 0.7805
# Epoch 39/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4612 - accuracy: 0.7735 - val_loss: 0.4535 - val_accuracy: 0.7886
# Epoch 40/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4593 - accuracy: 0.7857 - val_loss: 0.4519 - val_accuracy: 0.7886
# Epoch 41/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4613 - accuracy: 0.7735 - val_loss: 0.4552 - val_accuracy: 0.7886
# Epoch 42/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4539 - accuracy: 0.7857 - val_loss: 0.4559 - val_accuracy: 0.7805
# Epoch 43/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4522 - accuracy: 0.7939 - val_loss: 0.4554 - val_accuracy: 0.8049
# Epoch 44/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4527 - accuracy: 0.7857 - val_loss: 0.4572 - val_accuracy: 0.7967
# Epoch 45/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4528 - accuracy: 0.7673 - val_loss: 0.4627 - val_accuracy: 0.7805
# Epoch 46/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4502 - accuracy: 0.7959 - val_loss: 0.4603 - val_accuracy: 0.7886
# Epoch 47/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4483 - accuracy: 0.7755 - val_loss: 0.4614 - val_accuracy: 0.7886
# Epoch 48/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4476 - accuracy: 0.7898 - val_loss: 0.4566 - val_accuracy: 0.7967
# Epoch 49/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4463 - accuracy: 0.7980 - val_loss: 0.4584 - val_accuracy: 0.7967
# Epoch 50/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.4432 - accuracy: 0.7980 - val_loss: 0.4580 - val_accuracy: 0.7967
# 5/5 [==============================] - 0s 2ms/step

# %% [markdown]
# PRINT RESULTS

# %%
# Print results for each classifier
for name, metrics in results.items():
    print(f"Classifier: {name}")
    print(f"Accuracy: {metrics['Accuracy']:.4f}")
    print("Classification Report:")
    print(metrics['Classification Report'])
    print("=" * 40)

# Find the best-performing model
best_model = max(results, key=lambda x: results[x]["Accuracy"])
print(f"The best-performing model is: {best_model} with accuracy {results[best_model]['Accuracy']:.4f}")
# Out:
# Classifier: Logistic Regression
# Accuracy: 0.8442
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.96      0.89       100
#            1       0.89      0.63      0.74        54
#
#     accuracy                           0.84       154
#    macro avg       0.86      0.79      0.81       154
# weighted avg       0.85      0.84      0.84       154
#
# ========================================
# Classifier: Decision Tree
# Accuracy: 0.7403
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.85      0.81       100
#            1       0.66      0.54      0.59        54
#
#     accuracy                           0.74       154
#    macro avg       0.72      0.69      0.70       154
# weighted avg       0.73      0.74      0.73       154
#
# ========================================
# Classifier: Random Forest
# Accuracy: 0.7987
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.91      0.85       100
#            1       0.78      0.59      0.67        54
#
#     accuracy                           0.80       154
#    macro avg       0.79      0.75      0.76       154
# weighted avg       0.80      0.80      0.79       154
#
# ========================================
# Classifier: AdaBoost
# Accuracy: 0.8247
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.90      0.87       100
#            1       0.79      0.69      0.73        54
#
#     accuracy                           0.82       154
#    macro avg       0.81      0.79      0.80       154
# weighted avg       0.82      0.82      0.82       154
#
# ========================================
# Classifier: SVM
# Accuracy: 0.8377
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.95      0.88       100
#            1       0.87      0.63      0.73        54
#
#     accuracy                           0.84       154
#    macro avg       0.85      0.79      0.81       154
# weighted avg       0.84      0.84      0.83       154
#
# ========================================
# Classifier: K-Nearest Neighbors
# Accuracy: 0.7338
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.85      0.81       100
#            1       0.65      0.52      0.58        54
#
#     accuracy                           0.73       154
#    macro avg       0.71      0.68      0.69       154
# weighted avg       0.73      0.73      0.73       154
#
# ========================================
# Classifier: Naive Bayes
# Accuracy: 0.8312
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.89      0.87       100
#            1       0.78      0.72      0.75        54
#
#     accuracy                           0.83       154
#    macro avg       0.82      0.81      0.81       154
# weighted avg       0.83      0.83      0.83       154
#
# ========================================
# Classifier: XGBoost
# Accuracy: 0.7208
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.82      0.79       100
#            1       0.62      0.54      0.57        54
#
#     accuracy                           0.72       154
#    macro avg       0.69      0.68      0.68       154
# weighted avg       0.71      0.72      0.72       154
#
# ========================================
# Classifier: ANN
# Accuracy: 0.8377
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.94      0.88       100
#            1       0.85      0.65      0.74        54
#
#     accuracy                           0.84       154
#    macro avg       0.84      0.79      0.81       154
# weighted avg       0.84      0.84      0.83       154
#
# ========================================
# The best-performing model is: Logistic Regression with accuracy 0.8442

# %% [markdown]
# VISUALIZE RESULTS

# %%
import matplotlib.pyplot as plt

accuracy_scores = [results[classifier]["Accuracy"] for classifier in classifiers.keys()]
classifier_names = classifiers.keys()

plt.figure(figsize=(12, 6))
plt.bar(classifier_names, accuracy_scores, color='skyblue')
plt.xlabel('Classifier')
plt.ylabel('Accuracy')
plt.title('Classifier Accuracy Comparison')
plt.xticks(rotation=45)
plt.show()

# %%
from sklearn.metrics import roc_curve, auc

# Initialize an empty dictionary to store ROC data
roc_data = {}

for name, classifier in classifiers.items():
    # Check if the classifier supports probability estimates
    if hasattr(classifier, "predict_proba"):
        classifier.probability = True  # Enable probability estimates
    else:
        print(f"{name} does not support probability estimates and will not generate ROC curves.")
        continue

    classifier.fit(X_train, y_train)
    y_scores = classifier.predict_proba(X_test)[:, 1]

    # Compute ROC curve and AUC
    fpr, tpr, _ = roc_curve(y_test, y_scores)
    roc_auc = auc(fpr, tpr)

    # Store ROC data in the dictionary
    roc_data[name] = {
        "fpr": fpr,
        "tpr": tpr,
        "roc_auc": roc_auc
    }

# Create ROC plots for each classifier
plt.figure(figsize=(12, 8))
for name, data in roc_data.items():
    plt.plot(data["fpr"], data["tpr"], label=f'{name} (AUC = {data["roc_auc"]:.2f})')

plt.plot([0, 1], [0, 1], color='navy', linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curves')
plt.legend(loc="lower right")
plt.show()
# Out:
# SVM does not support probability estimates and will not generate ROC curves.
# ANN does not support probability estimates and will not generate ROC curves.

# %% [markdown]
# ENSEMBLE MODEL

# %%
print(best_classifiers.keys())
# Out:
# dict_keys(['Logistic Regression', 'AdaBoost', 'SVM', 'Naive Bayes', 'ANN'])

# %%
for i in range(y_pred_final.size):
    if y_pred_final[i] >= (len(best_classifiers)+1)/2:
        y_pred_final[i] = 1
    else:
        y_pred_final[i] = 0

# %%
accuracy_score(y_test, y_pred_final)
# Out:
# 0.8571428571428571

# %%
cm = confusion_matrix(y_test, y_pred_final)

# Create a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()

# %% [markdown]
# PREDICTION

# %%
from collections import Counter

# # Input data for prediction
# user_input_data = []

# # Prompt the user to enter values for each feature
# for feature_name in X.columns:
#     value = float(input(f"Enter the value for {feature_name}: "))
#     user_input_data.append(value)

user_input_data = [6,148,72,35,0,33.6,0.627,50] # sample input data

# Standardize the user input data using the same scaler
input_data = scaler.transform([user_input_data])

# Make predictions using each classifier on the input data
all_predictions = [predict(name, classifier, input_data) for name,classifier in best_classifiers.items()]

# Count the most common prediction among the models for the input data
predictions_for_input = [pred[0] for pred in all_predictions]
most_common_prediction = Counter(predictions_for_input).most_common(1)[0][0]

if most_common_prediction == 0:
    print("Non-Diabetic person")
else:
    print("Diabetic Person")
# Out:
# 1/1 [==============================] - 0s 30ms/step
# Diabetic Person
# c:\Users\abhik\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
